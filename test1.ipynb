# %%
import csv

d = dict()
with open('adult.csv') as csvfile:
  # 解析內容
  rows = list(csv.reader(csvfile))
  for row in rows[1:]:
    # print(row[2][:3], row[4])
    if row[2][:3] not in d:
      d[row[2][:3]] = 0
    d[row[2][:3]] = d[row[2][:3]] + int(row[4])

print(d)
# Out:
# {'775': 38, '833': 65, '215': 1001, '234': 910, '338': 475, '284': 642, '160': 1704, '209': 1409, '457': 107, '159': 1484, '280': 614, '141': 1159, '122': 1165, '205': 1490, '121': 1198, '245': 675, '176': 2251, '186': 1852, '288': 473, '292': 494, '193': 2008, '302': 540, '768': 89, '117': 2062, '109': 1428, '216': 1613, '168': 1679, '180': 1755, '367': 244, '190': 2189, '266': 749, '386': 349, '599': 74, '311': 492, '242': 881, '197': 1806, '544': 75, '841': 115, '265': 703, '507': 73, '885': 105, '172': 1644, '946': 82, '289': 680, '337': 537, '144': 1285, '128': 959, '101': 1356, '271': 665, '322': 385, '226': 1107, '518': 66, '251': 601, '237': 830, '563': 122, '147': 1250, '188': 2297, '594': 122, '293': 598, '149': 1440, '116': 1453, '105': 1228, '155': 1420, '183': 2037, '169': 1802, '191': 1929, '200': 1717, '309': 468, '162': 1633, '211': 1304, '124': 1442, '213': 1342, '212': 1144, '125': 1363, '446': 164, '276': 497, '516': 77, '343': 702, '346': 449, '268': 675, '202': 1
# ...
